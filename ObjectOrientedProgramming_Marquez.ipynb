# %%
# PROCEDURE 1: Creating a Class and Object in Python

# Step 1: Define a class named Car
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def display_info(self):
        return f"{self.year} {self.brand} {self.model}"

# Step 2: Create an object of the Car class
my_car = Car("Toyota", "Corolla", 2022)

# Step 3: Print the car details using the method
print(my_car.display_info())
# Out:
# 2022 Toyota Corolla

# %%
# TRY IT - Procedure 1: Laptop Class

# Step 1: Define a class named Laptop
class Laptop:
    def __init__(self, brand, processor, ram):
        self.brand = brand
        self.processor = processor
        self.ram = ram

    def get_specs(self):
        return f"Brand: {self.brand} | Processor: {self.processor} | RAM: {self.ram}GB"

# Step 2: Instantiate a Laptop object with specific values
my_laptop = Laptop("Asus", "Ryzen 7", 16)

# Step 3: Display the output using get_specs()
print(my_laptop.get_specs())
# Out:
# Brand: Asus | Processor: Ryzen 7 | RAM: 16GB

# %%
# PROCEDURE 2: Implementing Encapsulation in Python

# Step 1: Define a class with private attributes
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.__balance = balance  # Private attribute

    def deposit(self, amount):
        self.__balance += amount
        return f"New balance: ${self.__balance}"

    def get_balance(self):
        return f"Balance: ${self.__balance}"

# Step 2: Create an object and test encapsulation
account = BankAccount("Alice", 5000)

# Step 3: Deposit money and display the updated balance
print(account.deposit(1500))
print(account.get_balance())
# Out:
# New balance: $6500
# Balance: $6500

# %%
# TRY IT - Procedure 2: StudentRecord Class with Encapsulation

# Step 1: Define a class named StudentRecord with a private attribute
class StudentRecord:
    def __init__(self):
        self.__grades = []  # Private attribute

    def add_grade(self, grade):
        self.__grades.append(grade)
        return f"Grade {grade} added successfully."

    def get_grades(self):
        return f"Grades: {self.__grades}"

# Step 2: Create an object of StudentRecord
record = StudentRecord()

# Step 3: Add several grades using the method
print(record.add_grade(96))
print(record.add_grade(89))
print(record.add_grade(86))

# Step 4: Print the list of grades
print(record.get_grades())
# Out:
# Grade 96 added successfully.
# Grade 89 added successfully.
# Grade 86 added successfully.
# Grades: [96, 89, 86]

# %%
# PROCEDURE 3: Applying Inheritance in Python

# Step 1: Define a base class
class Person:
    def __init__(self, name):
        self.name = name

    def introduce(self):
        return f"Hi, I'm {self.name}."

# Step 2: Define a subclass that inherits from Person
class Student(Person):
    def introduce(self):
        return f"Hi, I'm {self.name}, and I'm a student."

# Step 3: Create objects and call methods
person = Person("Allen")
student = Student("Earl Jhay")

print(person.introduce())
print(student.introduce())
# Out:
# Hi, I'm Allen.
# Hi, I'm Earl Jhay, and I'm a student.

# %%
# TRY IT - Procedure 3: Device and Smartphone Inheritance

# Step 1: Define a base class called Device
class Device:
    def __init__(self, device_name):
        self.device_name = device_name

    def power_on(self):
        return f"{self.device_name} is now turning on."

# Step 2: Define a subclass Smartphone that overrides power_on()
class Smartphone(Device):
    def power_on(self):
        return f"{self.device_name} is booting up... Welcome!"

# Step 3: Instantiate objects from both classes
generic_device = Device("Generic Device")
my_phone = Smartphone("Tecno Pova")

# Step 4: Call power_on() methods to observe method overriding
print(generic_device.power_on())
print(my_phone.power_on())
# Out:
# Generic Device is now turning on.
# Tecno Pova is booting up... Welcome!

# %%
# PROCEDURE 4: Utilizing Polymorphism in Python

# Step 1: Define a base class
class Shape:
    def area(self):
        return "Calculating area..."

# Step 2: Define subclasses with their implementations
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Step 3: Create objects and call their methods
circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Circle area: {circle.area()}")
print(f"Rectangle area: {rectangle.area()}")
# Out:
# Circle area: 78.5
# Rectangle area: 24

# %%
# TRY IT - Procedure 4: Polymorphism with Device Subclasses

# Step 1: Define a base class named Device
class Device:
    def power_on(self):
        return "Device is turning on."

# Step 2: Create two subclasses with overridden power_on() methods
class Smartphone(Device):
    def power_on(self):
        return "Smartphone is booting up... Loading apps!"

class Laptop(Device):
    def power_on(self):
        return "Laptop is starting up... Running system checks!"

# Step 3: Write a function that accepts any Device object
def start_device(device):
    print(device.power_on())

# Step 4: Create instances and pass them to start_device()
phone = Smartphone()
laptop = Laptop()

start_device(phone)
start_device(laptop)
# Out:
# Smartphone is booting up... Loading apps!
# Laptop is starting up... Running system checks!

# %%
# PROCEDURE 5: Using Object-Oriented Libraries

# Step 1: Import the datetime module
import datetime

# Step 2: Create an object for the current date and time
current_time = datetime.datetime.now()

# Step 3: Print the formatted date and time
print("Current Date and Time:", current_time.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current Date and Time: 2026-04-25 02:02:56

# %%
# TRY IT - Procedure 5: Using random and os Modules

# Step 1: Import the random and os modules
import random
import os

# Step 2: Generate a random floating-point number between 0 and 1
random_number = random.random()
print(f"Random floating-point number: {random_number}")

# Step 3: Display the name of the operating system
os_name = os.name
print(f"Operating System: {os_name}")
# Out:
# Random floating-point number: 0.43020103700073575
# Operating System: nt

# %%
# PROCEDURE 6: Working with Class and Static Methods

# Step 1: Define a class with a static method
class MathOperations:
    @staticmethod
    def square(num):
        return num * num

# Step 2: Get user input
user_input = int(input("Enter a number to square: "))

# Step 3: Call the static method with user input
result = MathOperations.square(user_input)

# Step 4: Print the result
print("Square of", user_input, ":", result)
# Out:
# Square of 3 : 9

# %%
# TRY IT - Procedure 6: TemperatureConverter Static Method

# Step 1: Define a class with a static method for temperature conversion
class TemperatureConverter:
    @staticmethod
    def celsius_to_fahrenheit(celsius):
        return (celsius * 9 / 5) + 32

# Step 2: Prompt the user to enter a temperature in Celsius
celsius_input = float(input("Enter temperature in Celsius: "))

# Step 3: Convert using the static method and print the result
fahrenheit_result = TemperatureConverter.celsius_to_fahrenheit(celsius_input)
print(f"{celsius_input}°C is equal to {fahrenheit_result}°F")
# Out:
# 67.0°C is equal to 152.6°F

# %%
# PROCEDURE 7: Operator Overloading in Python

# Step 1: Define a class with overloaded operators
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def __add__(self, other):
        return BankAccount(self.balance + other.balance)

# Step 2: Create account objects and add their balances
account1 = BankAccount(5000)
account2 = BankAccount(3000)
total_balance = account1 + account2  # Combines the balances

# Step 3: Print the result
print(f"Total Balance: P{total_balance.balance}")
# Out:
# Total Balance: P8000

# %%
# TRY IT - Procedure 7: Vector Class with Operator Overloading

# Step 1: Define a class Vector with overloaded + and - operators
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __sub__(self, other):
        return Vector(self.x - other.x, self.y - other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

# Step 2: Create instances of Vector
v1 = Vector(2, 5)
v2 = Vector(4, 9)

# Step 3: Demonstrate vector addition and subtraction
result_add = v1 + v2
result_sub = v1 - v2

print(f"V1: {v1}")
print(f"V2: {v2}")
print(f"V1 + V2 = {result_add}")
print(f"V1 - V2 = {result_sub}")
# Out:
# V1: Vector(2, 5)
# V2: Vector(4, 9)
# V1 + V2 = Vector(6, 14)
# V1 - V2 = Vector(-2, -4)

# %%
# PROCEDURE 8: Abstract Classes and Methods in Python

from abc import ABC, abstractmethod

# Step 1: Define an abstract class
class Appliance(ABC):
    @abstractmethod
    def turn_on(self):
        pass

# Step 2: Define a subclass implementing the abstract method
class WashingMachine(Appliance):
    def turn_on(self):
        return "Washing machine is now running."

# Step 3: Create an object of the subclass and call the method
wm = WashingMachine()
print(wm.turn_on())
# Out:
# Washing machine is now running.

# %%
# TRY IT - Procedure 8: Refrigerator Subclass from Abstract Appliance

from abc import ABC, abstractmethod

# Step 1: Define the abstract base class
class Appliance(ABC):
    @abstractmethod
    def turn_on(self):
        pass

# Step 2: Create a subclass Refrigerator implementing turn_on()
class Refrigerator(Appliance):
    def turn_on(self):
        return "Refrigerator is now operating."

# Step 3: Instantiate a Refrigerator object and call turn_on()
fridge = Refrigerator()
print(fridge.turn_on())
# Out:
# Refrigerator is now operating.

# %%
# PROCEDURE 9: Implementing Method Resolution Order (MRO)

# Step 1: Define multiple classes
class A:
    def show(self):
        return "Class A"

class B(A):
    def show(self):
        return "Class B"

class C(A):
    def show(self):
        return "Class C"

class D(B, C):
    pass  # Inherits show() based on MRO

# Step 2: Create an object of class D and call the method
obj = D()
print(obj.show())  # Output depends on MRO
# Out:
# Class B

# %%
# TRY IT - Procedure 9: Exploring Multiple Inheritance and MRO

# Step 1: Define four classes each with a show() method
class Alpha:
    def show(self):
        return "Class Alpha"

class Beta(Alpha):
    def show(self):
        return "Class Beta"

class Gamma(Alpha):
    def show(self):
        return "Class Gamma"

class Delta(Beta, Gamma):
    def show(self):
        return "Class Delta"

# Step 2: Create an object of Delta and call show()
obj = Delta()
print(obj.show())

# Step 3: Print the Method Resolution Order
print("MRO:", Delta.mro())
# Out:
# Class Delta
# MRO: [<class '__main__.Delta'>, <class '__main__.Beta'>, <class '__main__.Gamma'>, <class '__main__.Alpha'>, <class 'object'>]

# %%
# SNIPPET 1: Car Class - Basic Object Creation

class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def display_info(self):
        return f"Car: {self.brand} {self.model}"

my_car = Car("Toyota", "Corolla")
print(my_car.display_info())
# Out:
# Car: Toyota Corolla

# %%
# SNIPPET 2: Student Class - Missing 'self' in Method (Bug)

class Student:
    def __init__(self, name, grade):
        self.name = name
        self.grade = grade

    def get_info(self):  
        return f"Student: {self.name}, Grade: {self.grade}"

student1 = Student("Marquez", "A")
print(student1.get_info())
# Out:
# Student: Marquez, Grade: A

# %%
# SNIPPET 3: BankAccount Class - Encapsulation with Private Attribute

class BankAccount:
    def __init__(self, account_holder, balance):
        self.__balance = balance  # Private attribute
        self.account_holder = account_holder

    def deposit(self, amount):
        self.__balance += amount
        return f"New Balance: {self.__balance}"

    def get_balance(self):
        return f"Balance: {self.__balance}"

account = BankAccount("John Doe", 1000)
print(account.deposit(500))
print(account.get_balance())
# Out:
# New Balance: 1500
# Balance: 1500

# %%
# SNIPPET 5: Vehicle, Car, ElectricCar - Multi-level Inheritance

class Vehicle:
    def move(self):
        return "Vehicle is moving"

class Car(Vehicle):
    def fuel_type(self):
        return "Uses gasoline"

class ElectricCar(Car):
    def fuel_type(self):
        return "Uses electricity"

tesla = ElectricCar()
print(tesla.move())
print(tesla.fuel_type())
# Out:
# Vehicle is moving
# Uses electricity

# %%
# SNIPPET 6: Device and Smartphone - Method Overriding

class Device:
    def power_on(self):
        return "Device is turning on"

class Smartphone(Device):
    def power_on(self):
        return "Smartphone is booting up"

phone = Smartphone()
print(phone.power_on())
# Out:
# Smartphone is booting up

# %%
# SNIPPET 7: Box Class - Operator Overloading with __add__

class Box:
    def __init__(self, weight):
        self.weight = weight

    def __add__(self, other):
        return Box(self.weight + other.weight)

box1 = Box(5)
box2 = Box(10)
box3 = box1 + box2
print(f"Total weight: {box3.weight} kg")
# Out:
# Total weight: 15 kg

# %%
# SNIPPET 8: Appliance and Fan - Abstract Class Implementation

from abc import ABC, abstractmethod

class Appliance(ABC):
    @abstractmethod
    def turn_on(self):
        pass

class Fan(Appliance):
    def turn_on(self):
        return "Fan is spinning"

fan = Fan()
print(fan.turn_on())
# Out:
# Fan is spinning

# %%
# SNIPPET 9: Engine, Wheels, Car - Multiple Inheritance and MRO

class Engine:
    def start(self):
        return "Engine started"

class Wheels:
    def roll(self):
        return "Wheels rolling"

class Car(Engine, Wheels):
    def drive(self):
        return "Car is moving"

my_car = Car()
print(my_car.start())
print(my_car.roll())
print(my_car.drive())
# Out:
# Engine started
# Wheels rolling
# Car is moving

# %%
# SNIPPET 10: MathOperations - Static Method with User Input

class MathOperations:
    @staticmethod
    def square(num):
        return num * num

number = int(input("Enter a number: "))
print("Square:", MathOperations.square(number))
# Out:
# Square: 25

# %%
# SNIPPET 11: Book Class - Missing Required Argument (Bug)

class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def get_info(self):
        return f"{self.title} by {self.author}"

book1 = Book("1984", "George Orwell") 
print(book1.get_info())
# Out:
# 1984 by George Orwell

# %%
# SNIPPET 12: Product Class - Object Initialization and Display

class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def get_details(self):
        return f"{self.name} costs ${self.price}"

product1 = Product("Laptop", 1200)
print(product1.get_details())
# Out:
# Laptop costs $1200

# %%
# SNIPPET 13: Person Class - Missing 'self' in Method (Bug)

class Person:
    def __init__(self, name):
        self.name = name

    def greet(self): 
        return f"Hello, {self.name}"

p = Person("Alice")
print(p.greet())
# Out:
# Hello, Alice

# %%
# SNIPPET 14: ATM Class - Conditional Logic in Methods

class ATM:
    def __init__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        if amount > self.balance:
            return "Insufficient balance"
        self.balance -= amount
        return f"Withdrawn {amount}, Remaining balance: {self.balance}"

atm = ATM(1000)
print(atm.withdraw(200))
# Out:
# Withdrawn 200, Remaining balance: 800

# %%
# SNIPPET 15: Employee Class - Calling Undefined Method (Bug)

class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
    def display(self):
        return f"Employee: {self.name}, Salary: {self.salary}"
emp1 = Employee("Michael", 5000)
print(emp1.display())  # display() is not defined - will raise AttributeError
# Out:
# Employee: Michael, Salary: 5000

# %%
# SNIPPET 16: Patient Class - Multiple Attributes in One Method

class Patient:
    def __init__(self, name, age, disease):
        self.name = name
        self.age = age
        self.disease = disease

    def get_info(self):
        return f"Patient: {self.name}, Age: {self.age}, Disease: {self.disease}"

patient1 = Patient("John Cruz", 45, "Diabetes")
print(patient1.get_info())
# Out:
# Patient: John Cruz, Age: 45, Disease: Diabetes

# %%
# SNIPPET 17: Teacher Class - Method Returning Formatted String

class Teacher:
    def __init__(self, name, subject):
        self.name = name
        self.subject = subject

    def teach(self):
        return f"{self.name} is teaching {self.subject}"

teacher1 = Teacher("Mr. Smith", "Mathematics")
print(teacher1.teach())
# Out:
# Mr. Smith is teaching Mathematics

# %%
# SNIPPET 18: Flight Class - Missing Required Argument (Bug)

class Flight:
    def __init__(self, flight_number, destination):
        self.flight_number = flight_number
        self.destination = destination

    def book_ticket(self):
        return f"Ticket booked for flight {self.flight_number} to {self.destination}"

flight1 = Flight(101, "Paris") 
print(flight1.book_ticket())
# Out:
# Ticket booked for flight 101 to Paris

# %%
# SNIPPET 19: SmartDevice Class - Default Parameter Value

class SmartDevice:
    def __init__(self, device_name, status="Off"):
        self.device_name = device_name
        self.status = status

    def turn_on(self):
        self.status = "On"
        return f"{self.device_name} is now {self.status}"

light = SmartDevice("Living Room Light")
print(light.turn_on())
# Out:
# Living Room Light is now On

# %%
# SNIPPET 20: Library Class - List Attribute with Add and Display Methods

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, title):
        self.books.append(title)
        return f"Book '{title}' added to the library"

    def show_books(self):
        return f"Available Books: {', '.join(self.books)}"

library = Library()
print(library.add_book("Python Programming"))
print(library.show_books())
# Out:
# Book 'Python Programming' added to the library
# Available Books: Python Programming
